# %% [markdown]
# ---
# title: External notebook - ipynb
# authors:
#   - name: Author name
# format:
#   pdf:
#     fig-format: pdf
#   html:
#     fig-format: svg
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %config InlineBackend.figure_formats = ['svg']

# %%
#| label: fig-external-ipynb
#| fig-cap: "Caption."

x = np.linspace(0,1,100)
y = x**2
plt.plot(x, y)

plt.xlabel('X-Axis Label')
plt.ylabel('Y-Axis Label')
plt.title('Sample Plot')
plt.show()
